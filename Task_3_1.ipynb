# %%
import numpy as np
import scipy as sc
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
col_names = ['Step number',
'Age (years)',
'Mass (M0)',
'Log10 Luminosity (L0)',
'Log10 Radius (R0)',
'Log10 Surface temperature (K)',
'Log10 Central temperature (K)',
'Log10 Central density (kg m-3)',
'Log10 Central pressure (N m-2)',
'Central electron degeneracy parameter',
'Central hydrogen mass fraction',
'Central helium mass fraction',
'Central carbon mass fraction',
'Central nitrogen mass fraction',
'Central oxygen mass fraction',
'Dynamical timescale (seconds)',
'Kelvin-Helmholtz timescale (years)',
'Nuclear timescale (years)',
'Luminosity from PP chain (L0)',
'Luminosity from CNO cycle (L0)',
'Luminosity from triple-alpha reactions (L0)',
'Luminosity from metal burning (L0)',
'Luminosity of neutrino losses (L0)',
'Mass of helium core (M0)',
'Mass of carbon core (M0)',
'Mass of oxygen core (M0)',
'Radius of helium core (R0)',
'Radius of carbon core (R0)',
'Radius of oxygen core (R0)']

# %%
data_1_5 = pd.read_fwf('Data1_5/Data0_01/summary_SI.txt', names=col_names, index_col=0)
data_20 = pd.read_fwf('Data20/Data0_01/summary_SI.txt', names=col_names, index_col=0)

# %%
data_1_5.describe()
# Out:
#         Age (years)   Mass (M0)  Log10 Luminosity (L0)  Log10 Radius (R0)  \
# count  9.370000e+02  937.000000             937.000000         937.000000
# mean   2.227771e+09    1.427318               2.099529           1.193150
# std    6.076870e+08    0.148165               0.980545           0.654534
# min    0.000000e+00    0.813854               0.774372           0.121963
# 25%    2.262975e+09    1.432461               1.134349           0.596715
# 50%    2.392756e+09    1.441671               1.943207           1.118388
# 75%    2.558946e+09    1.497608               2.650924           1.597759
# max    2.572441e+09    1.500000               4.260316           2.641091
#
#        Log10 Surface temperature (K)  Log10 Central temperature (K)  \
# count                     937.000000                     937.000000
# mean                        3.689997                       7.829178
# std                         0.099275                       0.324740
# ...

# %%
data_20.describe()
# Out:
#         Age (years)   Mass (M0)  Log10 Luminosity (L0)  Log10 Radius (R0)  \
# count  6.660000e+02  666.000000             666.000000         666.000000
# mean   8.401690e+06   19.768933               5.097848           2.287415
# std    2.660515e+06    0.260258               0.191163           0.874719
# min    0.000000e+00   19.367752               4.612980           0.744355
# 25%    9.041235e+06   19.478793               5.040950           1.364944
# 50%    9.056401e+06   19.972176               5.122818           2.930692
# 75%    9.758925e+06   19.973573               5.191899           2.973045
# max    9.886893e+06   20.000000               5.331627           3.075874
#
#        Log10 Surface temperature (K)  Log10 Central temperature (K)  \
# count                     666.000000                     666.000000
# mean                        3.892444                       8.215716
# std                         0.399513                       0.387934
# ...

# %%
# data_CGS = pd.read_fwf('Data1_5/Data0_0003/summary_CGS.txt', names=col_names, index_col=0)
# data_CGS
# (data_SI - data_CGS).iloc[:5, [6, 7]]

# %% [markdown]
# ---

# %% [markdown]
# # Task 3.1 Part 1

# %% [markdown]
# Investigate how surface temperature, luminosity, central density and central temperature change with time. How do they change in relation to each other? What does this tell you about what is happening to the star? Include plots to illustrate your answers.

# %% [markdown]
# ### Surface Temp. vs Time

# %%
# plt.figure(figsize=(8,6))
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

ax[0].plot(data_1_5['Age (years)']/1e9, data_1_5['Log10 Surface temperature (K)'], linestyle='--', c='b')
ax[0].grid();

ax[1].plot(data_20['Age (years)']/1e7, data_20['Log10 Surface temperature (K)'], linestyle='--', c='r')

ax[0].set_xlabel('Age [$10^{9}$ years]')
ax[0].set_ylabel('Log10 Surface temperature [K]')

ax[0].set_title('Mass 1.5 M☉ Star')
ax[1].set_title('Mass 20 M☉ Star')
fig.suptitle('Surface Temperature vs. Age', fontsize=16)

ax[1].set_xlabel('Age [$10^{7}$ years]')
ax[1].set_ylabel('Log10 Surface temperature [K]')
ax[1].grid();

# %% [markdown]
# ## Luminosity vs Time

# %% [markdown]
# ### Luminosity from PP Chain

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].plot(data_1_5['Age (years)']/1e9, data_1_5['Luminosity from PP chain (L0)'], linestyle='--', c='b')
ax[0].grid();
ax[1].plot(data_20['Age (years)']/1e7, data_20['Luminosity from PP chain (L0)'], linestyle='--', c='r')

ax[0].set_xlabel('Age [$10^{9}$ years]')
ax[0].set_ylabel('Luminosity from PP chain [L☉]')

ax[0].set_title('Mass 1.5 M☉ Star')
ax[1].set_title('Mass 20 M☉ Star')
fig.suptitle('Luminosity from PP Chain vs. Age', fontsize=16)

ax[1].set_xlabel('Age [$10^{7}$ years]')
ax[1].set_ylabel('Luminosity from PP chain [L☉]')
ax[1].grid();

# %% [markdown]
# ### Luminosity from CNO Cycle

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].plot(data_1_5['Age (years)']/1e9, data_1_5['Luminosity from CNO cycle (L0)']/1e4, linestyle='--', c='b')
ax[0].grid();
ax[1].plot(data_20['Age (years)']/1e7, data_20['Luminosity from CNO cycle (L0)']/1e5, linestyle='--', c='r')

ax[0].set_xlabel('Age [$10^{9}$ years]')
ax[0].set_ylabel('Luminosity from CNO cycle [$10^{4}$ L☉]')

ax[0].set_title('Mass 1.5 M☉ Star')
ax[1].set_title('Mass 20 M☉ Star')
fig.suptitle('Luminosity from CNO Cycle vs. Age', fontsize=16)

ax[1].set_xlabel('Age [$10^{7}$ years]')
ax[1].set_ylabel('Luminosity from CNO cycle [$10^{5}$ L☉]')
ax[1].grid();

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].plot(data_1_5['Age (years)']/1e9, data_1_5['Luminosity from CNO cycle (L0)'], linestyle='--', c='b')
ax[0].grid();
ax[1].plot(data_20['Age (years)']/1e7, data_20['Luminosity from CNO cycle (L0)'], linestyle='--', c='r')

ax[0].set_yscale('log')
ax[1].set_yscale('log')

ax[0].set_xlabel('Age [$10^{9}$ years]')
ax[0].set_ylabel('Log Luminosity from CNO cycle [L☉]')

ax[0].set_title('Mass 1.5 M☉ Star')
ax[1].set_title('Mass 20 M☉ Star')
fig.suptitle('Log Luminosity from CNO Cycle vs. Age', fontsize=16)

ax[1].set_xlabel('Age [$10^{7}$ years]')
ax[1].set_ylabel('Log Luminosity from CNO cycle [L☉]')
ax[1].grid();

# %% [markdown]
# ### Luminosity from Triple-Alpha Reactions

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].plot(data_1_5['Age (years)']/1e9, data_1_5['Luminosity from triple-alpha reactions (L0)']/1e5, linestyle='--', c='b')
ax[0].grid();
ax[1].plot(data_20['Age (years)']/1e7, data_20['Luminosity from triple-alpha reactions (L0)']/1e6, linestyle='--', c='r')

ax[0].set_xlabel('Age [$10^{9}$ years]')
ax[0].set_ylabel('Luminosity from triple-alpha reactions [$10^{5}$ L☉]')

ax[0].set_title('Mass 1.5 M☉ Star')
ax[1].set_title('Mass 20 M☉ Star')
fig.suptitle('Luminosity from Triple-Alpha Reactions vs. Age', fontsize=16)

ax[1].set_xlabel('Age [$10^{7}$ years]')
ax[1].set_ylabel('Luminosity from triple-alpha reactions [$10^{6}$ L☉]')
ax[1].grid();

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].plot(data_1_5['Age (years)']/1e9, data_1_5['Luminosity from triple-alpha reactions (L0)'], linestyle='--', c='b')
ax[0].grid();
ax[1].plot(data_20['Age (years)']/1e7, data_20['Luminosity from triple-alpha reactions (L0)'], linestyle='--', c='r')

ax[0].set_yscale('log')
ax[1].set_yscale('log')

ax[0].set_xlabel('Age [$10^{9}$ years]')
ax[0].set_ylabel('Log Luminosity from triple-alpha reactions [L☉]')

ax[0].set_title('Mass 1.5 M☉ Star')
ax[1].set_title('Mass 20 M☉ Star')
fig.suptitle('Log Luminosity from Triple-Alpha Reactions vs. Age', fontsize=16)

ax[1].set_xlabel('Age [$10^{7}$ years]')
ax[1].set_ylabel('Log Luminosity from triple-alpha reactions [L☉]')
ax[1].grid();

# %% [markdown]
# ### Luminosity from Metal Burning

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].plot(data_1_5['Age (years)']/1e9, data_1_5['Luminosity from metal burning (L0)']*1e7, linestyle='--', c='b')
ax[0].grid();
ax[1].plot(data_20['Age (years)']/1e7, data_20['Luminosity from metal burning (L0)']/1e7, linestyle='--', c='r')

ax[0].set_xlabel('Age [$10^{9}$ years]')
ax[0].set_ylabel('Luminosity from metal burning [$10^{-7}$ L☉]')

ax[0].set_title('Mass 1.5 M☉ Star')
ax[1].set_title('Mass 20 M☉ Star')
fig.suptitle('Luminosity from Metal Burning vs. Age', fontsize=16)

ax[1].set_xlabel('Age [$10^{7}$ years]')
ax[1].set_ylabel('Luminosity from metal burning [$10^{7}$ L☉]')
ax[1].grid();

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].plot(data_1_5['Age (years)']/1e9, data_1_5['Luminosity from metal burning (L0)'], linestyle='--', c='b')
ax[0].grid();
ax[1].plot(data_20['Age (years)']/1e7, data_20['Luminosity from metal burning (L0)'], linestyle='--', c='r')

ax[0].set_yscale('log')
ax[1].set_yscale('log')

ax[0].set_xlabel('Age [$10^{9}$ years]')
ax[0].set_ylabel('Log Luminosity from metal burning [L☉]')

ax[0].set_title('Mass 1.5 M☉ Star')
ax[1].set_title('Mass 20 M☉ Star')
fig.suptitle('Log Luminosity from Metal Burning vs. Age', fontsize=16)

ax[1].set_xlabel('Age [$10^{7}$ years]')
ax[1].set_ylabel('Log Luminosity from metal burning [L☉]')
ax[1].grid();

# %% [markdown]
# ### Luminosity of Neutrino Loss

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].plot(data_1_5['Age (years)']/1e9, data_1_5['Luminosity of neutrino losses (L0)']/1e2, linestyle='-', c='b')
ax[0].grid();
ax[1].plot(data_20['Age (years)']/1e7, data_20['Luminosity of neutrino losses (L0)']/1e7, linestyle='-', c='r')

ax[0].set_xlabel('Age [$10^{9}$ years]')
ax[0].set_ylabel('Luminosity of neutrino losses [$10^{2}$ L☉]')

ax[0].set_title('Mass 1.5 M☉ Star')
ax[1].set_title('Mass 20 M☉ Star')
fig.suptitle('Luminosity from Neutrino Loss vs. Age', fontsize=16)

ax[1].set_xlabel('Age [$10^{7}$ years]')
ax[1].set_ylabel('Luminosity of neutrino losses [$10^{7}$ L☉]')
ax[1].grid();

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].plot(data_1_5['Age (years)']/1e9, data_1_5['Luminosity of neutrino losses (L0)'], linestyle='-', c='b')
ax[0].grid();
ax[1].plot(data_20['Age (years)']/1e7, data_20['Luminosity of neutrino losses (L0)'], linestyle='-', c='r')

ax[0].set_yscale('log')
ax[1].set_yscale('log')

ax[0].set_xlabel('Age [$10^{9}$ years]')
ax[0].set_ylabel('Log Luminosity of neutrino losses [L☉]')

ax[0].set_title('Mass 1.5 M☉ Star')
ax[1].set_title('Mass 20 M☉ Star')
fig.suptitle('Log Luminosity from Neutrino Loss vs. Age', fontsize=16)

ax[1].set_xlabel('Age [$10^{7}$ years]')
ax[1].set_ylabel('Log Luminosity of neutrino losses [L☉]')
ax[1].grid();

# %%
total_lum_1_5 = (data_1_5['Luminosity from PP chain (L0)'] + data_1_5['Luminosity from CNO cycle (L0)'] + data_1_5['Luminosity from triple-alpha reactions (L0)'] + data_1_5['Luminosity of neutrino losses (L0)'] + data_1_5['Luminosity from metal burning (L0)'])/100
total_lum_20 = (data_20['Luminosity from PP chain (L0)'] + data_20['Luminosity from CNO cycle (L0)'] + data_20['Luminosity from triple-alpha reactions (L0)'] + data_20['Luminosity of neutrino losses (L0)'] + data_20['Luminosity from metal burning (L0)'])/100

fig, ax = plt.subplots(1, 2, figsize=(10, 5))

# ax[0].plot(data_1_5['Age (years)']/1e9, ((data_1_5['Luminosity of neutrino losses (L0)'])/total_lum_1_5), 
#            linestyle='--', c='b', alpha=0.9, zorder=1, label='Neutrino')

# ax[0].plot(data_1_5['Age (years)']/1e9, ((data_1_5['Luminosity from CNO cycle (L0)'])/total_lum_1_5), 
#            linestyle='-', c='black', alpha=0.5, label='CNO')

# ax[0].plot(data_1_5['Age (years)']/1e9, ((data_1_5['Luminosity from PP chain (L0)'])/total_lum_1_5), 
#            linestyle='-', c='r', alpha=0.9, label='PP')

# ax[0].plot(data_1_5['Age (years)']/1e9, ((data_1_5['Luminosity from triple-alpha reactions (L0)'])/total_lum_1_5), 
#            linestyle='-.', c='g', alpha=0.9, zorder=2, label=r'3$\alpha$')

# ax[0].plot(data_1_5['Age (years)']/1e9, ((data_1_5['Luminosity from metal burning (L0)'])/total_lum_1_5), 
#            linestyle='--', c='y', alpha=0.9, zorder=2, label='Metal')

ax[0].plot(data_1_5['Age (years)']/1e9, total_lum_1_5,
          linestyle='-', c='b', alpha=0.9, zorder=1)

#--------------------------------------------------------------------------------------------------------------------#
# ax[1].plot(data_20['Age (years)']/1e7, ((data_20['Luminosity of neutrino losses (L0)'])/total_lum_20), 
#            linestyle='--', c='b', alpha=0.9, zorder=1, label='Neutrino')

# ax[1].plot(data_20['Age (years)']/1e7, ((data_20['Luminosity from CNO cycle (L0)'])/total_lum_20), 
#            linestyle='-', c='black', alpha=0.5, label='CNO')

# ax[1].plot(data_20['Age (years)']/1e7, ((data_20['Luminosity from PP chain (L0)'])/total_lum_20), 
#            linestyle='-', c='r', alpha=0.9, label='PP')

# ax[1].plot(data_20['Age (years)']/1e7, ((data_20['Luminosity from triple-alpha reactions (L0)'])/total_lum_20), 
#            linestyle='-.', c='g', alpha=0.9, zorder=2, label=r'3$\alpha$')

# ax[1].plot(data_20['Age (years)']/1e7, ((data_20['Luminosity from metal burning (L0)'])/total_lum_20), 
#            linestyle='--', c='y', alpha=0.9, zorder=2, label='Metal')

ax[1].plot(data_20['Age (years)']/1e9, total_lum_20,
          linestyle='-', c='b', alpha=0.9, zorder=1)

ax[0].set_yscale('log')
ax[1].set_yscale('log')
# ax[0].set_xlim(left=1e0)

ax[0].set_xlabel('Age [$10^{9}$ years]')
ax[0].set_ylabel('Log Luminosity [L☉]')

ax[0].set_title('Mass 1.5 M☉ Star')
ax[1].set_title('Mass 20 M☉ Star')
fig.suptitle('Log Luminosity From All Sources vs. Age', fontsize=16)

ax[1].set_xlabel('Age [$10^{7}$ years]')
ax[1].set_ylabel('Log Luminosity [L☉]')
# ax[0].legend()
# ax[1].legend()
ax[0].grid(alpha=0.45);
ax[1].grid(alpha=0.45);
plt.tight_layout();

# %%
# data_1_5 = pd.read_fwf('Data1_5/Data0_01/summary_SI.txt', names=col_names)[650:]
# data_20 = pd.read_fwf('Data20/Data0_01/summary_SI.txt', names=col_names)[500:]

# total_lum_1_5 = (data_1_5['Luminosity from PP chain (L0)'] + data_1_5['Luminosity from CNO cycle (L0)'] + data_1_5['Luminosity from triple-alpha reactions (L0)'] + data_1_5['Luminosity of neutrino losses (L0)'] + data_1_5['Luminosity from metal burning (L0)'])/100
# total_lum_20 = (data_20['Luminosity from PP chain (L0)'] + data_20['Luminosity from CNO cycle (L0)'] + data_20['Luminosity from triple-alpha reactions (L0)'] + data_20['Luminosity of neutrino losses (L0)'] + data_20['Luminosity from metal burning (L0)'])/100

# fig, ax = plt.subplots(2, 1, figsize=(12, 8))

# ax[0].plot(data_1_5['Age (years)']/1e9, ((data_1_5['Luminosity of neutrino losses (L0)'])/total_lum_1_5), 
#            linestyle='--', c='b', alpha=0.9, zorder=1, label='Neutrino')

# ax[0].plot(data_1_5['Age (years)']/1e9, ((data_1_5['Luminosity from CNO cycle (L0)'])/total_lum_1_5), 
#            linestyle='-', c='black', alpha=0.5, label='CNO')

# ax[0].plot(data_1_5['Age (years)']/1e9, ((data_1_5['Luminosity from PP chain (L0)'])/total_lum_1_5), 
#            linestyle='-', c='r', alpha=0.9, label='PP')

# ax[0].plot(data_1_5['Age (years)']/1e9, ((data_1_5['Luminosity from triple-alpha reactions (L0)'])/total_lum_1_5), 
#            linestyle='-.', c='g', alpha=0.9, zorder=2, label=r'3$\alpha$')

# ax[0].plot(data_1_5['Age (years)']/1e9, ((data_1_5['Luminosity from metal burning (L0)'])/total_lum_1_5), 
#            linestyle='--', c='y', alpha=0.9, zorder=2, label='Metal')

# #--------------------------------------------------------------------------------------------------------------------#
# ax[1].plot(data_20['Age (years)']/1e7, ((data_20['Luminosity of neutrino losses (L0)'])/total_lum_20), 
#            linestyle='--', c='b', alpha=0.9, zorder=1, label='Neutrino')

# ax[1].plot(data_20['Age (years)']/1e7, ((data_20['Luminosity from CNO cycle (L0)'])/total_lum_20), 
#            linestyle='-', c='black', alpha=0.5, label='CNO')

# ax[1].plot(data_20['Age (years)']/1e7, ((data_20['Luminosity from PP chain (L0)'])/total_lum_20), 
#            linestyle='-', c='r', alpha=0.9, label='PP')

# ax[1].plot(data_20['Age (years)']/1e7, ((data_20['Luminosity from triple-alpha reactions (L0)'])/total_lum_20), 
#            linestyle='-.', c='g', alpha=0.9, zorder=2, label=r'3$\alpha$')

# ax[1].plot(data_20['Age (years)']/1e7, ((data_20['Luminosity from metal burning (L0)'])/total_lum_20), 
#            linestyle='--', c='y', alpha=0.9, zorder=2, label='Metal')

# # ax[0].set_xscale('log')
# # ax[1].set_yscale('log')

# ax[0].set_xlabel('Age [$10^{9}$ years]')
# ax[0].set_ylabel('Percentage of Total Luminosity [L☉]')

# ax[0].set_title('Mass 1.5 M☉ Star')
# ax[1].set_title('Mass 20 M☉ Star')
# fig.suptitle('Percentage Luminosity From All Sources vs. Age', fontsize=16)

# ax[1].set_xlabel('Age [$10^{7}$ years]')
# ax[1].set_ylabel('Percentage of Total Luminosity [L☉]')
# ax[0].legend()
# ax[1].legend()
# ax[0].grid(alpha=0.45);
# ax[1].grid(alpha=0.45);

# plt.tight_layout();

# data_1_5 = pd.read_fwf('Data1_5/Data0_01/summary_SI.txt', names=col_names, index_col=0)
# data_20 = pd.read_fwf('Data20/Data0_01/summary_SI.txt', names=col_names, index_col=0)

# %% [markdown]
# ## Central Density vs Time

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].plot(data_1_5['Age (years)']/1e9, data_1_5['Log10 Central density (kg m-3)'], linestyle='-', c='b')
ax[0].grid();
ax[1].plot(data_20['Age (years)']/1e7, data_20['Log10 Central density (kg m-3)'], linestyle='-', c='r')

ax[0].set_xlabel('Age [$10^{9}$ years]')
ax[0].set_ylabel('Log10 Central density [kg $m^{-3}$]')

ax[0].set_title('Mass 1.5 M☉ Star')
ax[1].set_title('Mass 20 M☉ Star')
fig.suptitle('Central Density vs. Age', fontsize=16)

ax[1].set_xlabel('Age [$10^{7}$ years]')
ax[1].set_ylabel('Log10 Central density [kg $m^{-3}$]')
ax[1].grid();

# %% [markdown]
# ## Central Temp. vs Time

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].plot(data_1_5['Age (years)']/1e9, data_1_5['Log10 Central temperature (K)'], linestyle='-', c='b')
ax[0].grid();
ax[1].plot(data_20['Age (years)']/1e7, data_20['Log10 Central temperature (K)'], linestyle='-', c='r')

ax[0].set_xlabel('Age [$10^{9}$ years]')
ax[0].set_ylabel('Log10 Central temperature [K]')

ax[0].set_title('Mass 1.5 M☉ Star')
ax[1].set_title('Mass 20 M☉ Star')
fig.suptitle('Central Temperature vs. Age', fontsize=16)

ax[1].set_xlabel('Age [$10^{7}$ years]')
ax[1].set_ylabel('Log10 Central temperature [K]')
ax[1].grid();

# %% [markdown]
# ---

# %% [markdown]
# # Task 3.1 Part 2

# %% [markdown]
# The detailed structure files list several parameters for each radial grid point of the stellar interior. There is a structure file for each time step as well. Examine how the stellar interior changes with time. Plot each of density, temperature, hydrogen mass fraction, and luminosity against radius at a few well- chosen distributed time steps (at least three). What can you say about how these properties change with radius? How do they change as the star evolves?
# Compare the results for your group’s assigned stellar masses and discuss the differences.

# %%
det_col_names = ['Lagrangian mass coordinate (M☉)',
'Radius coordinate (R☉)',
'Luminosity (L☉)',
'Total pressure (N m-2)',
'Density (kg m-3)',
'Temperature (K)',
'Specific internal energy (J kg-1)',
'Specific entropy (J K-1 kg-1)',
'Specific heat at constant pressure (J K-1 kg-1)',
'First adiabatic exponent',
'Adiabatic temperature gradient',
'Mean molecular weight',
'Electron number density (m-3)',
'Electron pressure (N m-2)',
'Radiation pressure (N m-2)',
'Radiative temperature gradient',
'Material temperature gradient',
'Convective velocity (m s-1)',
'Rosseland mean opacity (m2 kg-1)',
'Power per unit mass from all nuclear reactions, excluding neutrino losses (W kg-1)',
'Power per unit mass from PP chain (W kg-1)',
'Power per unit mass from CNO cycle (W kg-1)',
'Power per unit mass from triple-alpha reaction (W kg-1)',
'Power loss per unit mass in nuclear neutrinos (W kg-1)',
'Power loss per unit mass in non-nuclear neutrinos (W kg-1)',
'Power per unit mass from gravitational contraction (W kg-1)',
'Hydrogen mass fraction (all ionization stages)',
'Molecular hydrogen mass fraction',
'Singly-ionized hydrogen mass fraction',
'Helium mass fraction (all ionization stages)',
'Singly-ionized helium mass fraction',
'Doubly-ionized helium mass fraction',
'Carbon mass fraction',
'Nitrogren mass fraction',
'Oxygen mass fraction',
'Electron degeneracy parameter']

# %%
## Steps 0, 300, and 800 for 1.5M
## Steps 0, 220, and 500 for 20M

det_data_1_5 = pd.read_fwf('Data1_5/Data0_01/Detailed/structure_00000.txt', names=det_col_names)
det_data_20 = pd.read_fwf('Data20/Data0_01/Detailed/structure_00000.txt', names=det_col_names)

det_data_1_5_mid = pd.read_fwf('Data1_5/Data0_01/Detailed/structure_00300.txt', names=det_col_names)
det_data_20_mid = pd.read_fwf('Data20/Data0_01/Detailed/structure_00220.txt', names=det_col_names)

det_data_1_5_last = pd.read_fwf('Data1_5/Data0_01/Detailed/structure_00800.txt', names=det_col_names)
det_data_20_last = pd.read_fwf('Data20/Data0_01/Detailed/structure_00500.txt', names=det_col_names)

# %%
det_data_1_5.describe()
# Out:
#        Lagrangian mass coordinate (M☉)  Radius coordinate (R☉)  \
# count                       199.000000              199.000000
# mean                          0.672895                0.444349
# std                           0.632927                0.469223
# min                           0.000019                0.006459
# 25%                           0.035151                0.083361
# 50%                           0.455053                0.220553
# 75%                           1.469160                0.703226
# max                           1.500000                1.324228
#
#        Luminosity (L☉)  Total pressure (N m-2)  Density (kg m-3)  \
# count       199.000000            1.990000e+02        199.000000
# mean          3.865904            9.607279e+15      42178.009092
# std           2.386113            9.278885e+15      36849.336654
# min           0.000937            5.686019e+02          0.000011
# 25%           1.243974            1.084064e+13        258.573409
# ...

# %%
det_data_20.describe()
# Out:
#        Lagrangian mass coordinate (M☉)  Radius coordinate (R☉)  \
# count                       199.000000              199.000000
# mean                          7.663014                1.859736
# std                           8.189453                1.835261
# min                           0.000010                0.013110
# 25%                           0.263462                0.433152
# 50%                           3.383943                1.088408
# 75%                          17.406687                2.716238
# max                          20.000000                5.550795
#
#        Luminosity (L☉)  Total pressure (N m-2)  Density (kg m-3)  \
# count       199.000000            1.990000e+02        199.000000
# mean      27773.858773            1.287857e+15       2547.877744
# std       16222.557047            1.060369e+15       1869.691939
# min           0.568628            8.796043e+02          0.000001
# 25%       10731.289050            4.675328e+13        297.756798
# ...

# %% [markdown]
# ## Density vs. Radius

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ax[0].plot(det_data_1_5['Radius coordinate (R☉)'], np.log(det_data_1_5['Density (kg m-3)']), linestyle='-', c='b')
ax[1].plot(det_data_1_5_mid['Radius coordinate (R☉)'], np.log(det_data_1_5_mid['Density (kg m-3)']), linestyle='-', c='b')
ax[2].plot(det_data_1_5_last['Radius coordinate (R☉)'], np.log(det_data_1_5_last['Density (kg m-3)']), linestyle='-', c='b')

ax[0].set_title(str(data_1_5['Age (years)'][0])+' Years')
ax[1].set_title(str(np.round(data_1_5['Age (years)'][300]/1e9, 3))+r'$\times 10^9$ Years')
ax[2].set_title(str(np.round(data_1_5['Age (years)'][800]/1e9, 3))+r'$\times 10^9$ Years')

fig.suptitle('Log Density vs. Radius for Mass 1.5 M☉ Star', fontsize=16)

ax[0].set_xlabel('Radius [R☉]')
ax[0].set_ylabel('Log Density [kg $m^{-3}$]')
ax[1].set_xlabel('Radius [R☉]')
ax[1].set_ylabel('Log Density [kg $m^{-3}$]')
ax[2].set_xlabel('Radius [R☉]')
ax[2].set_ylabel('Log Density [kg $m^{-3}$]')

ax[0].grid();
ax[1].grid();
ax[2].grid();
plt.tight_layout();

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ax[0].plot(det_data_20['Radius coordinate (R☉)'], np.log(det_data_20['Density (kg m-3)']), linestyle='-', c='b')
ax[1].plot(det_data_20_mid['Radius coordinate (R☉)'], np.log(det_data_20_mid['Density (kg m-3)']), linestyle='-', c='b')
ax[2].plot(det_data_20_last['Radius coordinate (R☉)'], np.log(det_data_20_last['Density (kg m-3)']), linestyle='-', c='b')

ax[0].set_title(str(data_20['Age (years)'][0])+' Years')
ax[1].set_title(str(np.round(data_20['Age (years)'][220]/1e6, 3))+r'$\times 10^6$ Years')
ax[2].set_title(str(np.round(data_20['Age (years)'][500]/1e6, 3))+r'$\times 10^6$ Years')

fig.suptitle('Log Density vs. Radius for Mass 20 M☉ Star', fontsize=16)

ax[0].set_xlabel('Radius [R☉]')
ax[0].set_ylabel('Log Density [kg $m^{-3}$]')
ax[1].set_xlabel('Radius [R☉]')
ax[1].set_ylabel('Log Density [kg $m^{-3}$]')
ax[2].set_xlabel('Radius [R☉]')
ax[2].set_ylabel('Log Density [kg $m^{-3}$]')

ax[0].grid();
ax[1].grid();
ax[2].grid();
plt.tight_layout();

# %% [markdown]
# ## Hydrogen Mass Fraction vs. Radius

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ax[0].plot(det_data_1_5['Radius coordinate (R☉)'], det_data_1_5['Hydrogen mass fraction (all ionization stages)'], linestyle='-', c='b')
ax[1].plot(det_data_1_5_mid['Radius coordinate (R☉)'], det_data_1_5_mid['Hydrogen mass fraction (all ionization stages)'], linestyle='-', c='b')
ax[2].plot(det_data_1_5_last['Radius coordinate (R☉)'], det_data_1_5_last['Hydrogen mass fraction (all ionization stages)'], linestyle='-', c='b')

ax[0].set_xscale('log')
ax[1].set_xscale('log')
ax[2].set_xscale('log')

ax[0].set_title(str(data_1_5['Age (years)'][0])+' Years')
ax[1].set_title(str(np.round(data_1_5['Age (years)'][300]/1e9, 3))+r'$\times 10^9$ Years')
ax[2].set_title(str(np.round(data_1_5['Age (years)'][800]/1e9, 3))+r'$\times 10^9$ Years')

fig.suptitle('Hydrogen Mass Fraction (all ionization stages) vs. Radius for Mass 1.5 M☉ Star', fontsize=16)

ax[0].set_xlabel('Log Radius [R☉]')
ax[0].set_ylabel('Hydrogen Mass Fraction')
ax[1].set_xlabel('Log Radius [R☉]')
ax[1].set_ylabel('Hydrogen Mass Fraction')
ax[2].set_xlabel('Log Radius [R☉]')
ax[2].set_ylabel('Hydrogen Mass Fraction')

ax[0].grid();
ax[1].grid();
ax[2].grid();
plt.tight_layout();

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ax[0].plot(det_data_20['Radius coordinate (R☉)'], det_data_20['Hydrogen mass fraction (all ionization stages)'], linestyle='-', c='b')
ax[1].plot(det_data_20_mid['Radius coordinate (R☉)'], det_data_20_mid['Hydrogen mass fraction (all ionization stages)'], linestyle='-', c='b')
ax[2].plot(det_data_20_last['Radius coordinate (R☉)'], det_data_20_last['Hydrogen mass fraction (all ionization stages)'], linestyle='-', c='b')

ax[0].set_xscale('log')
ax[1].set_xscale('log')
ax[2].set_xscale('log')

ax[0].set_title(str(data_20['Age (years)'][0])+' Years')
ax[1].set_title(str(np.round(data_20['Age (years)'][220]/1e6, 3))+r'$\times 10^6$ Years')
ax[2].set_title(str(np.round(data_20['Age (years)'][500]/1e6, 3))+r'$\times 10^6$ Years')

fig.suptitle('Hydrogen Mass Fraction (all ionization stages) vs. Radius for Mass 20 M☉ Star', fontsize=16)

ax[0].set_xlabel('Log Radius [R☉]')
ax[0].set_ylabel('Hydrogen Mass Fraction')
ax[1].set_xlabel('Log Radius [R☉]')
ax[1].set_ylabel('Hydrogen Mass Fraction')
ax[2].set_xlabel('Log Radius [R☉]')
ax[2].set_ylabel('Hydrogen Mass Fraction')

ax[0].grid();
ax[1].grid();
ax[2].grid();
plt.tight_layout();

# %% [markdown]
# ## Luminosity vs. Radius

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ax[0].plot(np.log(det_data_1_5['Radius coordinate (R☉)']), np.log(det_data_1_5['Luminosity (L☉)']), linestyle='-', c='b')
ax[1].plot(np.log(det_data_1_5_mid['Radius coordinate (R☉)']), np.log(det_data_1_5_mid['Luminosity (L☉)']), linestyle='-', c='b')
ax[2].plot(np.log(det_data_1_5_last['Radius coordinate (R☉)']), np.log(det_data_1_5_last['Luminosity (L☉)']), linestyle='-', c='b')

ax[0].set_title(str(data_1_5['Age (years)'][0])+' Years')
ax[1].set_title(str(np.round(data_1_5['Age (years)'][300]/1e9, 3))+r'$\times 10^9$ Years')
ax[2].set_title(str(np.round(data_1_5['Age (years)'][800]/1e9, 3))+r'$\times 10^9$ Years')

fig.suptitle('Log Luminosity vs. Radius for Mass 1.5 M☉ Star', fontsize=16)

ax[0].set_xlabel('Log Radius [R☉]')
ax[0].set_ylabel('Log Luminosity (L☉)')
ax[1].set_xlabel('Log Radius [R☉]')
ax[1].set_ylabel('Log Luminosity (L☉)')
ax[2].set_xlabel('Log Radius [R☉]')
ax[2].set_ylabel('Log Luminosity (L☉)')

ax[0].grid();
ax[1].grid();
ax[2].grid();
plt.tight_layout();

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ax[0].plot(np.log(det_data_20['Radius coordinate (R☉)']), np.log(det_data_20['Luminosity (L☉)']), linestyle='-', c='b')
ax[1].plot(np.log(det_data_20_mid['Radius coordinate (R☉)']), np.log(det_data_20_mid['Luminosity (L☉)']), linestyle='-', c='b')
ax[2].plot(np.log(det_data_20_last['Radius coordinate (R☉)']), np.log(det_data_20_last['Luminosity (L☉)']), linestyle='-', c='b')

ax[0].set_title(str(data_20['Age (years)'][0])+' Years')
ax[1].set_title(str(np.round(data_20['Age (years)'][220]/1e6, 3))+r'$\times 10^6$ Years')
ax[2].set_title(str(np.round(data_20['Age (years)'][500]/1e6, 3))+r'$\times 10^6$ Years')

fig.suptitle('Log Luminosity vs. Radius for Mass 20 M☉ Star', fontsize=16)

ax[0].set_xlabel('Log Radius [R☉]')
ax[0].set_ylabel('Log Luminosity (L☉)')
ax[1].set_xlabel('Log Radius [R☉]')
ax[1].set_ylabel('Log Luminosity (L☉)')
ax[2].set_xlabel('Log Radius [R☉]')
ax[2].set_ylabel('Log Luminosity (L☉)')

ax[0].grid();
ax[1].grid();
ax[2].grid();
plt.tight_layout();
