# %%
import numpy as np
import scipy as sc
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
col_names = ['Step number',
'Age (years)',
'Mass (M0)',
'Log10 Luminosity (L0)',
'Log10 Radius (R0)',
'Log10 Surface temperature (K)',
'Log10 Central temperature (K)',
'Log10 Central density (kg m-3)',
'Log10 Central pressure (N m-2)',
'Central electron degeneracy parameter',
'Central hydrogen mass fraction',
'Central helium mass fraction',
'Central carbon mass fraction',
'Central nitrogen mass fraction',
'Central oxygen mass fraction',
'Dynamical timescale (seconds)',
'Kelvin-Helmholtz timescale (years)',
'Nuclear timescale (years)',
'Luminosity from PP chain (L0)',
'Luminosity from CNO cycle (L0)',
'Luminosity from triple-alpha reactions (L0)',
'Luminosity from metal burning (L0)',
'Luminosity of neutrino losses (L0)',
'Mass of helium core (M0)',
'Mass of carbon core (M0)',
'Mass of oxygen core (M0)',
'Radius of helium core (R0)',
'Radius of carbon core (R0)',
'Radius of oxygen core (R0)']

# %%
data_1_5 = pd.read_fwf('Data1_5/Data0_01/summary_SI.txt', names=col_names, index_col=0)
data_20 = pd.read_fwf('Data20/Data0_01/summary_SI.txt', names=col_names, index_col=0)

# %%
data_20.describe()
# Out:
#         Age (years)   Mass (M0)  Log10 Luminosity (L0)  Log10 Radius (R0)  \
# count  6.660000e+02  666.000000             666.000000         666.000000
# mean   8.401690e+06   19.768933               5.097848           2.287415
# std    2.660515e+06    0.260258               0.191163           0.874719
# min    0.000000e+00   19.367752               4.612980           0.744355
# 25%    9.041235e+06   19.478793               5.040950           1.364944
# 50%    9.056401e+06   19.972176               5.122818           2.930692
# 75%    9.758925e+06   19.973573               5.191899           2.973045
# max    9.886893e+06   20.000000               5.331627           3.075874
#
#        Log10 Surface temperature (K)  Log10 Central temperature (K)  \
# count                     666.000000                     666.000000
# mean                        3.892444                       8.215716
# std                         0.399513                       0.387934
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Luminosity from PP Chain

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

ax[0].plot(data_1_5['Age (years)']/1e9, np.log(data_1_5['Luminosity from PP chain (L0)']), linestyle='--', c='b', label='PP chain')
ax[0].plot(data_1_5['Age (years)']/1e9, np.log(data_1_5['Luminosity from CNO cycle (L0)']), linestyle='--', c='r', label='CNO cycle')
ax[0].plot(data_1_5['Age (years)']/1e9, np.log(data_1_5['Luminosity from triple-alpha reactions (L0)']), linestyle='--', c='g', label='Triple-alpha reactions')
ax[0].plot(data_1_5['Age (years)']/1e9, np.log(data_1_5['Luminosity of neutrino losses (L0)']), linestyle='--', c='black', label='Neutrino losses')
ax[1].plot(data_20['Age (years)']/1e7, np.log(data_20['Luminosity from PP chain (L0)']), linestyle='--', c='b', label='PP chain')
ax[1].plot(data_20['Age (years)']/1e7, np.log(data_20['Luminosity from CNO cycle (L0)']), linestyle='--', c='r', label='CNO cycle')
ax[1].plot(data_20['Age (years)']/1e7, np.log(data_20['Luminosity from triple-alpha reactions (L0)']), linestyle='--', c='g', label='Triple-alpha reactions')
ax[1].plot(data_20['Age (years)']/1e7, np.log(data_20['Luminosity of neutrino losses (L0)']), linestyle='--', c='black', label='Neutrino losses')



ax[0].set_xlabel('Age [$10^{9}$ years]')
ax[0].set_ylabel('Log Luminosity in L☉')
ax[0].set_title('Mass 1.5 M☉ Star')
ax[1].set_title('Mass 20 M☉ Star')
fig.suptitle('Log Luminosity from PP Chain, CNO cycle, Triple-a vs. Age', fontsize=16)

ax[1].set_xlabel('Age [$10^{7}$ years]')
ax[1].set_ylabel('Log Luminosity in L☉')
ax[0].grid()
ax[1].grid()

# Add legends
ax[0].legend()
ax[1].legend()
plt.savefig("luminosity_PP_CNO_3a.png")
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
total_lumen_1_5 = data_1_5['Luminosity from PP chain (L0)'] + data_1_5['Luminosity from CNO cycle (L0)'] + data_1_5['Luminosity from triple-alpha reactions (L0)'] + data_1_5['Luminosity of neutrino losses (L0)']


total_lumen_20 = data_20['Luminosity from PP chain (L0)'] + data_20['Luminosity from CNO cycle (L0)'] + data_20['Luminosity from triple-alpha reactions (L0)'] + data_20['Luminosity of neutrino losses (L0)']

ax[0].plot(data_1_5['Age (years)']/1e9, data_1_5['Luminosity from PP chain (L0)']/total_lumen_1_5*100, linestyle='-', c='b', label='PP chain')
ax[0].plot(data_1_5['Age (years)']/1e9, data_1_5['Luminosity from CNO cycle (L0)']/total_lumen_1_5*100, linestyle='-', c='r',alpha = 0.7, label='CNO cycle')
ax[0].plot(data_1_5['Age (years)']/1e9, data_1_5['Luminosity from triple-alpha reactions (L0)']/total_lumen_1_5*100, linestyle='--', c='g', label='Triple-alpha reactions')
ax[0].plot(data_1_5['Age (years)']/1e9, data_1_5['Luminosity of neutrino losses (L0)']/total_lumen_1_5*100, linestyle='--', c='black', label='Neutrino losses')

#ax[0].grid()
ax[1].plot(data_20['Age (years)'], data_20['Luminosity from PP chain (L0)']/total_lumen_20*100, linestyle='-', c='b', label='PP chain')
ax[1].plot(data_20['Age (years)'], data_20['Luminosity from CNO cycle (L0)']/total_lumen_20*100, linestyle='-', c='r',label='CNO cycle')
ax[1].plot(data_20['Age (years)'], data_20['Luminosity from triple-alpha reactions (L0)']/total_lumen_20*100, linestyle='--', c='g', label='Triple-alpha reactions')
ax[1].plot(data_20['Age (years)'], data_20['Luminosity of neutrino losses (L0)']/total_lumen_20*100, linestyle='--', c='black', label='Neutrino losses')


ax[0].set_xlabel('Age [$10^{9}$ years]')
ax[0].set_ylabel('Luminosity %')
ax[0].set_title('Mass 1.5 M☉ Star')
ax[1].set_title('Mass 20 M☉ Star')
fig.suptitle('Luminosity from PP Chain, CNO cycle, Triple-a vs. Age', fontsize=16)

ax[1].set_xlabel('Age [$10^{7}$ years]')
ax[1].set_ylabel('Luminosity %')
ax[0].grid()
ax[1].grid()

# Add legends
ax[0].legend()
ax[1].legend()
plt.savefig("luminosity_percentage.png")
plt.show()

# %%
age_1_5 = np.array(data_1_5['Age (years)'])
age_20 = np.array(data_20['Age (years)'])
age_1_5[1:]-age_1_5[:-1]
# Out:
# array([1.81443685e+04, 1.81443684e+04, 2.17732422e+04, 2.61278906e+04,
#        3.13534683e+04, 3.76241630e+04, 4.51489950e+04, 5.41787940e+04,
#        6.50145520e+04, 7.80174640e+04, 9.36209560e+04, 1.12345147e+05,
#        1.34814176e+05, 1.61777012e+05, 1.94132413e+05, 2.32958900e+05,
#        2.79550670e+05, 3.35460820e+05, 4.02552970e+05, 4.83063570e+05,
#        5.79676280e+05, 6.95611540e+05, 8.34733850e+05, 1.00168061e+06,
#        1.20201674e+06, 1.44242009e+06, 1.73090415e+06, 2.07708490e+06,
#        2.49250190e+06, 2.99100230e+06, 3.58920270e+06, 4.30704330e+06,
#        5.16845200e+06, 6.20214240e+06, 7.44257080e+06, 8.93108500e+06,
#        1.07173020e+07, 1.28607624e+07, 1.54329148e+07, 1.85194983e+07,
#        2.22233970e+07, 2.66680770e+07, 3.20016920e+07, 3.84020310e+07,
#        2.76494620e+07, 2.76494620e+07, 2.76494620e+07, 2.76494620e+07,
#        2.76494620e+07, 3.31793550e+07, 3.98152250e+07, 4.77782710e+07,
# ...

# %%
plt.plot(np.arange(0, len(age_1_5)), data_1_5['Age (years)'])

# %% [markdown]
# plot the power per unit
# mass for each reaction against the radius from the centre.

# %%
col_names_extended = ['Lagrangian mass coordinate (M0)',
             'Radius coordinate (R0)',
             'Luminosity (L0)',
             'Total pressure (N m-2)',
             'Density (kg m-3)',
             'Temperature (K)',
             'Specific internal energy (J kg-1)',
             'Specific entropy (J K-1 kg-1)',
             'Specific heat at constant pressure (J K-1 kg-1)',
             'First adiabatic exponent',
             'Adiabatic temperature gradient',
             'Mean molecular weight',
             'Electron number density (m-3)',
             'Electron pressure (N m-2)',
             'Radiation pressure (N m-2)',
             'Radiative temperature gradient',
             'Material temperature gradient',
             'Convective velocity (m s-1)',
             'Rosseland mean opacity (m2 kg-1)',
             'Power per unit mass from all nuclear reactions, excluding neutrino losses (W kg-1)',
             'Power per unit mass from PP chain (W kg-1)',
             'Power per unit mass from CNO cycle (W kg-1)',
             'Power per unit mass from triple-alpha reaction (W kg-1)',
             'Power loss per unit mass in nuclear neutrinos (W kg-1)',
             'Power loss per unit mass in non-nuclear neutrinos (W kg-1)',
             'Power per unit mass from gravitational contraction (W kg-1)',
             'Hydrogen mass fraction (all ionization stages)',
             'Molecular hydrogen mass fraction',
             'Singly-ionized hydrogen mass fraction',
             'Helium mass fraction (all ionization stages)',
             'Singly-ionized helium mass fraction',
             'Doubly-ionized helium mass fraction',
             'Carbon mass fraction',
             'Nitrogren mass fraction',
             'Oxygen mass fraction',
             'Electron degeneracy parameter']

data_1_5_extended_early = pd.read_fwf('Data1_5/Data0_01/Detailed/structure_00000.txt', names=col_names_extended, index_col=0)
data_1_5_extended_mid = pd.read_fwf('Data1_5/Data0_01/Detailed/structure_00150.txt', names=col_names_extended, index_col=0)
data_1_5_extended_end = pd.read_fwf('Data1_5/Data0_01/Detailed/structure_00900.txt', names=col_names_extended, index_col=0)

# %%
data_1_5.describe()
# Out:
#         Age (years)   Mass (M0)  Log10 Luminosity (L0)  Log10 Radius (R0)  \
# count  9.370000e+02  937.000000             937.000000         937.000000
# mean   2.227771e+09    1.427318               2.099529           1.193150
# std    6.076870e+08    0.148165               0.980545           0.654534
# min    0.000000e+00    0.813854               0.774372           0.121963
# 25%    2.262975e+09    1.432461               1.134349           0.596715
# 50%    2.392756e+09    1.441671               1.943207           1.118388
# 75%    2.558946e+09    1.497608               2.650924           1.597759
# max    2.572441e+09    1.500000               4.260316           2.641091
#
#        Log10 Surface temperature (K)  Log10 Central temperature (K)  \
# count                     937.000000                     937.000000
# mean                        3.689997                       7.829178
# std                         0.099275                       0.324740
# ...

# %%
#data_20_extended = pd.read_fwf('Data20/Data0_01/Detailed/structure_00374.txt', names=col_names_extended, index_col=0)

data_20_extended_early = pd.read_fwf('Data20/Data0_01/Detailed/structure_00000.txt', names=col_names_extended, index_col=0)
data_20_extended_mid = pd.read_fwf('Data20/Data0_01/Detailed/structure_00300.txt', names=col_names_extended, index_col=0)
data_20_extended_end = pd.read_fwf('Data20/Data0_01/Detailed/structure_00600.txt', names=col_names_extended, index_col=0)

# %%
fig, ax = plt.subplots(1, 3, figsize=(12, 5))
fig.suptitle('Power per unit mass versus radius and age', fontsize=16)

age_mid = str(np.round(age_1_5[68]/1e7, 0))
age_end = str(np.round(age_1_5[660]/1e7, 0))

#'Power per unit mass from PP chain (W kg-1)'
ax[0].plot(data_1_5_extended_early['Radius coordinate (R0)'], 
           data_1_5_extended_early['Power per unit mass from PP chain (W kg-1)'], 
           linestyle='-', c='r', label='Age 0')

ax[0].plot(data_1_5_extended_mid['Radius coordinate (R0)'],
           data_1_5_extended_mid['Power per unit mass from PP chain (W kg-1)'], 
           linestyle='-', c='g',  label='Age ' + age_mid + " e7 years")

ax[0].plot(data_1_5_extended_end['Radius coordinate (R0)'], 
           data_1_5_extended_end['Power per unit mass from PP chain (W kg-1)'], 
           linestyle='-', c='b',  label='Age ' + age_end + " e7 years")

ax[1].plot(data_1_5_extended_early['Radius coordinate (R0)'], 
           data_1_5_extended_early['Power per unit mass from CNO cycle (W kg-1)'], 
           linestyle='-', c='r', label='Age 0')

ax[1].plot(data_1_5_extended_mid['Radius coordinate (R0)'], 
           data_1_5_extended_mid['Power per unit mass from CNO cycle (W kg-1)'], 
           linestyle='-', c='g', label='Age ' + age_mid + " e7 years")

ax[1].plot(data_1_5_extended_end['Radius coordinate (R0)'], 
           data_1_5_extended_end['Power per unit mass from CNO cycle (W kg-1)'], 
           linestyle='-', c='b', label='Age ' + age_end + " e7 years")

ax[2].plot(data_1_5_extended_early['Radius coordinate (R0)'],
           data_1_5_extended_early['Power per unit mass from triple-alpha reaction (W kg-1)'], 
           linestyle='-', c='r', label='Age 0')

ax[2].plot(data_1_5_extended_mid['Radius coordinate (R0)'], 
           data_1_5_extended_mid['Power per unit mass from triple-alpha reaction (W kg-1)'], 
           linestyle='-', c='g', label='Age ' + age_mid + " e7 years")

ax[2].plot(data_1_5_extended_end['Radius coordinate (R0)'],
           data_1_5_extended_end['Power per unit mass from triple-alpha reaction (W kg-1)'],
           linestyle='-', c='b',  label='Age ' + age_end + " e7 years")

ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[0].set_yscale('log')
ax[1].set_yscale('log')
ax[2].set_yscale('log')
ax[0].set_xscale('log')
ax[1].set_xscale('log')
ax[2].set_xscale('log')
ax[0].grid()
ax[1].grid()
ax[2].grid()
ax[0].set_xlabel('Log Radius in (R0)')
ax[1].set_xlabel('Log Radius in (R0)')
ax[2].set_xlabel('Log Radius in (R0)')
ax[0].set_ylabel('Log Power per unit mass from PP chain (W kg-1)')
ax[1].set_ylabel('Log Power per unit mass from CNO cycle (W kg-1)')
ax[2].set_ylabel('Log Power per unit mass from triple-alpha reaction (W kg-1)')
ax[0].set_xlim(0.001, 10)
ax[1].set_xlim(0.001, 10)
ax[2].set_xlim(0.001, 10)

# Adjust the layout to add space between the subplots
plt.subplots_adjust(wspace=0.4)  # Adjust the value as needed for the desired spacing
plt.savefig("Power_unit_mass_1_5.png")
plt.show()

# %%
fig, ax = plt.subplots(1, 3, figsize=(12, 5))

#'Power per unit mass from PP chain (W kg-1)'
age_mid = str(np.round(age_20[68]/1e5,0))
age_end = str(np.round(age_20[660]/1e5,0))
ax[0].plot(data_20_extended_early['Radius coordinate (R0)'], data_20_extended_early['Power per unit mass from PP chain (W kg-1)'], linestyle='-', c='r', label='Age 0 years')
ax[0].plot(data_20_extended_mid['Radius coordinate (R0)'],
           data_20_extended_mid['Power per unit mass from PP chain (W kg-1)'], 
           linestyle='-', c='g',  label='Age ' + age_mid + " e5 years")

ax[0].plot(data_20_extended_end['Radius coordinate (R0)'], 
           data_20_extended_end['Power per unit mass from PP chain (W kg-1)'], 
           linestyle='-', c='b',  label='Age ' + age_end + " e5 years")



ax[1].plot(data_20_extended_early['Radius coordinate (R0)'],
           data_20_extended_early['Power per unit mass from CNO cycle (W kg-1)'], 
           linestyle='-', c='r', label='Age 0 years')

ax[1].plot(data_20_extended_mid['Radius coordinate (R0)'], 
           data_20_extended_mid['Power per unit mass from CNO cycle (W kg-1)'], 
           linestyle='-', c='g', label='Age ' + age_mid + " e5 years")

ax[1].plot(data_20_extended_early['Radius coordinate (R0)'], 
           data_20_extended_end['Power per unit mass from CNO cycle (W kg-1)'], 
           linestyle='-', c='b', label='Age ' + age_end + " e5 years")



ax[2].plot(data_20_extended_early['Radius coordinate (R0)'],
           data_20_extended_early['Power per unit mass from triple-alpha reaction (W kg-1)'],
           linestyle='-', c='r', label='Age 0 years$')
ax[2].plot(data_20_extended_mid['Radius coordinate (R0)'], 
           data_20_extended_mid['Power per unit mass from triple-alpha reaction (W kg-1)'], 
           linestyle='-', c='g', label='Age ' + age_mid + " e5 years")
ax[2].plot(data_20_extended_end['Radius coordinate (R0)'],
           data_20_extended_end['Power per unit mass from triple-alpha reaction (W kg-1)'],
           linestyle='-', c='b',  label='Age ' + age_end + " e5 years")



ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[0].set_yscale('log')
ax[1].set_yscale('log')
ax[2].set_yscale('log')
ax[0].set_xscale('log')
ax[1].set_xscale('log')
ax[2].set_xscale('log')
ax[0].grid()
ax[1].grid()
ax[2].grid()
ax[0].set_xlabel('Log Radius in (R☉)')
ax[1].set_xlabel('Log Radius in (R☉)')
ax[2].set_xlabel('Log Radius in (R☉)')
ax[0].set_ylabel('Log Power per unit mass from PP chain (W kg-1)')
plt.savefig("Power_unit_mass_20.png")
#ax[0].set_title('Mass 1.5 M☉ Star')
#ax[1].set_title('Mass 20 M☉ Star')
fig.suptitle('Power per unit mass from PP Chain, CNO cycle, Triple-a vs. Radius for a Mass 20 M☉ Star', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Power per unit mass from PP Chain, CNO cycle, Triple-a vs. Radius for a Mass 20 M☉ Star')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the ages
age_mid = str(np.round(age_20[68] / 1e5, 0))
age_end = str(np.round(age_20[660] / 1e5, 0))

# Create subplots for each age
fig1, ax1 = plt.subplots(figsize=(10, 6))
fig2, ax2 = plt.subplots(figsize=(10, 6))
fig3, ax3 = plt.subplots(figsize=(10, 6))

# Define linestyles
linestyles = ['-', '--', '-.', ':', '-']

# Plot for the first age
for i, (fraction, linestyle) in enumerate(zip(['Helium mass fraction (all ionization stages)', 'Hydrogen mass fraction (all ionization stages)', 'Carbon mass fraction', 'Nitrogren mass fraction', 'Oxygen mass fraction'], linestyles)):
    ax1.plot(data_20_extended_early['Radius coordinate (R0)'], data_20_extended_early[fraction], linestyle=linestyle, color='C'+str(i), label=fraction)

ax1.set_xlabel('Radius in (R☉)')
ax1.set_ylabel('Mass Fraction')
ax1.grid()
ax1.legend()
fig1.suptitle(f'Mass Fractions vs. Radius (Age: 0 years)', fontsize=16)

# Plot for the second age
for i, (fraction, linestyle) in enumerate(zip(['Helium mass fraction (all ionization stages)', 'Hydrogen mass fraction (all ionization stages)', 'Carbon mass fraction', 'Nitrogren mass fraction', 'Oxygen mass fraction'], linestyles)):
    ax2.plot(data_20_extended_mid['Radius coordinate (R0)'], data_20_extended_mid[fraction], linestyle=linestyle, color='C'+str(i), label=fraction)

ax2.set_xlabel('Radius in (R☉)')
ax2.set_ylabel('Mass Fraction')
ax2.grid()
ax2.legend()
fig2.suptitle(f'Mass Fractions vs. Radius (Age: {age_mid} e5 years)', fontsize=16)

# Plot for the third age
for i, (fraction, linestyle) in enumerate(zip(['Helium mass fraction (all ionization stages)', 'Hydrogen mass fraction (all ionization stages)', 'Carbon mass fraction', 'Nitrogren mass fraction', 'Oxygen mass fraction'], linestyles)):
    ax3.plot(data_20_extended_end['Radius coordinate (R0)'], data_20_extended_end[fraction], linestyle=linestyle, color='C'+str(i), label=fraction)

ax3.set_xlabel('Radius in (R☉)')
ax3.set_ylabel('Mass Fraction')
ax3.grid()
ax3.legend()
fig3.suptitle(f'Mass Fractions vs. Radius (Age: {age_end} e5 years)', fontsize=16)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the ages
age_mid = str(np.round(age_20[68] / 1e5, 0))
age_end = str(np.round(age_20[660] / 1e5, 0))

# Create figure and axes for the first two subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Plot for the first age
for fraction, linestyle in zip(['Nitrogren mass fraction', 'Oxygen mass fraction', 'Carbon mass fraction'], ['-', '--', '-.']):
    axs[0].plot(data_20_extended_early['Radius coordinate (R0)'], data_20_extended_early[fraction], linestyle=linestyle, label=fraction)

# Plot for the second age
for fraction, linestyle in zip(['Nitrogren mass fraction', 'Oxygen mass fraction', 'Carbon mass fraction'], ['-', '--', '-.']):
    axs[1].plot(data_20_extended_mid['Radius coordinate (R0)'], data_20_extended_mid[fraction], linestyle=linestyle, label=fraction)

# Set labels, title, legend, and grid for the first subplot
axs[0].set_xlabel('Radius in (R☉)')
axs[0].set_ylabel('Mass Fraction')
axs[0].legend()
axs[0].set_title(f'Mass Fractions vs. Radius (Age: {age_mid} e5 years)')
axs[0].grid()

# Set labels, title, legend, and grid for the second subplot
axs[1].set_xlabel('Radius in (R☉)')
axs[1].set_ylabel('Mass Fraction')
axs[1].legend()
axs[1].set_title(f'Mass Fractions vs. Radius (Age: {age_end} e5 years)')
axs[1].grid()

# Create a new figure and a subplot with two plots for the third age
fig2, axs2 = plt.subplots(1, 2, figsize=(12, 6))

# Plot for the third age in linear scale
for fraction, linestyle in zip(['Nitrogren mass fraction', 'Oxygen mass fraction', 'Carbon mass fraction'], ['-', '--', '-.']):
    axs2[0].plot(data_20_extended_end['Radius coordinate (R0)'], data_20_extended_end[fraction], linestyle=linestyle, label=fraction)

# Plot for the third age in logarithmic scale
for fraction, linestyle in zip(['Nitrogren mass fraction', 'Oxygen mass fraction', 'Carbon mass fraction'], ['-', '--', '-.']):
    axs2[1].plot(data_20_extended_end['Radius coordinate (R0)'], data_20_extended_end[fraction], linestyle=linestyle, label=fraction)

# Set labels, title, legend, and grid for the first subplot of the third figure
axs2[0].set_xlabel('Radius in (R☉)')
axs2[0].set_ylabel('Mass Fraction')
axs2[0].legend()
axs2[0].set_title(f'Mass Fractions vs. Radius (Age: {age_end} e5 years) - Linear Scale')

# Set labels, title, legend, and grid for the second subplot of the third figure with logarithmic scale
axs2[1].set_xlabel('Radius in (R☉)')
axs2[1].set_ylabel('Mass Fraction')
axs2[1].legend()
axs2[1].set_title(f'Mass Fractions vs. Radius (Age: {age_end} e5 years) - Log Scale')
axs2[1].set_yscale('log')

plt.tight_layout()
plt.show()

# %% [markdown]
#     3.4

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

ax[0].plot(data_1_5['Age (years)']/1e9, data_1_5['Luminosity of neutrino losses (L0)'], linestyle='-', c='blue', label='Mass = 1,5 M☉')
ax[0].plot(data_20['Age (years)']/1e7,data_20['Luminosity of neutrino losses (L0)'], linestyle='-', c='red', label='Mass = 20 M☉')



ax[0].set_xlabel('Age [$10^{9}$ years]')
ax[0].set_ylabel('Log Luminosity in L☉')
ax[0].set_title('Mass 1.5 M☉ Star')
ax[1].set_title('Mass 20 M☉ Star')
fig.suptitle('Log Luminosity Neutrino loss vs. Age', fontsize=16)
ax[0].set_yscale('log')
ax[1].set_xlabel('Age [$10^{7}$ years]')
ax[1].set_ylabel('Log Luminosity in L☉')
ax[0].grid()
ax[1].grid()

# Add legends
ax[0].legend()
ax[1].legend()
plt.savefig("luminosity_PP_CNO_3a.png")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd

# Load the dataset
data = data_1_5 # Replace "your_dataset.csv" with the actual file path

# Define the luminosity columns
luminosity_columns = ['Luminosity from PP chain (L☉)', 'Luminosity from CNO cycle (L☉)', 'Luminosity from triple-alpha reactions (L☉)']

# Define the reaction rates for neutron production (arbitrary values for demonstration)
reaction_rates = {
    'Luminosity from PP chain (L☉)': 1.2,
    'Luminosity from CNO cycle (L☉)': 0.8,
    'Luminosity from triple-alpha reactions (L☉)': 0.5
}

# Calculate the total number of neutrons generated
total_neutron_production = 0
for col in luminosity_columns:
    luminosity_W = 10 ** data[col]  # Convert luminosity to watts
    neutron_production_rate = reaction_rates[col] * luminosity_W
    total_neutron_production += neutron_production_rate.sum()  # Sum over all rows

print("Total number of neutrons generated:", total_neutron_production)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /chalmers/groups/anaconda/anaconda2023/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /chalmers/groups/anaconda/anaconda2023/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /chalmers/groups/anaconda/anaconda2023/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Luminosity from PP chain (L☉)'
#
# ...
