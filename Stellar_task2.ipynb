# %%
import numpy as np
import scipy as sc
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
col_names = ['Step number',
'Age (years)',
'Mass (M0)',
'Log10 Luminosity (L0)',
'Log10 Radius (R0)',
'Log10 Surface temperature (K)',
'Log10 Central temperature (K)',
'Log10 Central density (kg m-3)',
'Log10 Central pressure (N m-2)',
'Central electron degeneracy parameter',
'Central hydrogen mass fraction',
'Central helium mass fraction',
'Central carbon mass fraction',
'Central nitrogen mass fraction',
'Central oxygen mass fraction',
'Dynamical timescale (seconds)',
'Kelvin-Helmholtz timescale (years)',
'Nuclear timescale (years)',
'Luminosity from PP chain (L0)',
'Luminosity from CNO cycle (L0)',
'Luminosity from triple-alpha reactions (L0)',
'Luminosity from metal burning (L0)',
'Luminosity of neutrino losses (L0)',
'Mass of helium core (M0)',
'Mass of carbon core (M0)',
'Mass of oxygen core (M0)',
'Radius of helium core (R0)',
'Radius of carbon core (R0)',
'Radius of oxygen core (R0)']

# %%
data_0_1 = pd.read_fwf('Stellar data/m0.1.txt', names=col_names, index_col=0)
data_0_5 = pd.read_fwf('Stellar data/m0.5.txt', names=col_names, index_col=0)
data_1 = pd.read_fwf('Stellar data/m1.txt', names=col_names, index_col=0)
data_1_5 = pd.read_fwf('Stellar data/m1.5.txt', names=col_names, index_col=0)
data_2 = pd.read_fwf('Stellar data/m2.txt', names=col_names, index_col=0)
data_3 = pd.read_fwf('Stellar data/m3.txt', names=col_names, index_col=0)
data_5 = pd.read_fwf('Stellar data/m5.txt', names=col_names, index_col=0)
data_8 = pd.read_fwf('Stellar data/m8.txt', names=col_names, index_col=0)
data_10 = pd.read_fwf('Stellar data/m10.txt', names=col_names, index_col=0)
data_15 = pd.read_fwf('Stellar data/m15.txt', names=col_names, index_col=0)
data_20 = pd.read_fwf('Stellar data/m20.txt', names=col_names, index_col=0)
data_30 = pd.read_fwf('Stellar data/m30.txt', names=col_names, index_col=0)
data_50 = pd.read_fwf('Stellar data/m50.txt', names=col_names, index_col=0)
data_100 = pd.read_fwf('Stellar data/m100.txt', names=col_names, index_col=0)

# %%
data_0_1.describe()
# Out:
#         Age (years)    Mass (M0)  Log10 Luminosity (L0)  Log10 Radius (R0)  \
# count  1.355000e+03  1355.000000            1355.000000        1355.000000
# mean   2.619507e+12     0.096993              -3.228836          -1.042921
# std    1.821041e+12     0.002132               0.746963           0.276622
# min    0.000000e+00     0.094534              -4.927976          -1.545032
# 25%    8.523994e+11     0.094602              -3.062226          -1.319155
# 50%    2.423058e+12     0.097306              -2.978775          -0.870740
# 75%    4.631647e+12     0.099063              -2.850579          -0.859125
# max    4.701140e+12     0.100000              -2.218088          -0.843553
#
#        Log10 Surface temperature (K)  Log10 Central temperature (K)  \
# count                    1355.000000                    1355.000000
# mean                        3.475941                       6.687379
# std                         0.103696                       0.221801
# ...

# %%
#list with Log10 Central temperature (K), first iteration
temp_central = np.array([data_0_1['Log10 Central temperature (K)'][1],
                        data_0_5['Log10 Central temperature (K)'][1],
                        data_1['Log10 Central temperature (K)'][1],
                        data_2['Log10 Central temperature (K)'][1],
                        data_3['Log10 Central temperature (K)'][1],
                        data_5['Log10 Central temperature (K)'][1],
                        data_8['Log10 Central temperature (K)'][1],
                        data_10['Log10 Central temperature (K)'][1],
                        data_15['Log10 Central temperature (K)'][1],
                        data_20['Log10 Central temperature (K)'][1],
                        data_30['Log10 Central temperature (K)'][1],
                        data_50['Log10 Central temperature (K)'][1],
                        data_100['Log10 Central temperature (K)'][1]])

density_central = np.array([data_0_1['Log10 Central density (kg m-3)'][1],
                        data_0_5['Log10 Central density (kg m-3)'][1],
                        data_1['Log10 Central density (kg m-3)'][1],
                        data_2['Log10 Central density (kg m-3)'][1],
                        data_3['Log10 Central density (kg m-3)'][1],
                        data_5['Log10 Central density (kg m-3)'][1],
                        data_8['Log10 Central density (kg m-3)'][1],
                        data_10['Log10 Central density (kg m-3)'][1],
                        data_15['Log10 Central density (kg m-3)'][1],
                        data_20['Log10 Central density (kg m-3)'][1],
                        data_30['Log10 Central density (kg m-3)'][1],
                        data_50['Log10 Central density (kg m-3)'][1],
                        data_100['Log10 Central density (kg m-3)'][1]])

luminosity = np.array([data_0_1['Log10 Luminosity (L0)'][1],
                        data_0_5['Log10 Luminosity (L0)'][1],
                        data_1['Log10 Luminosity (L0)'][1],
                        data_2['Log10 Luminosity (L0)'][1],
                        data_3['Log10 Luminosity (L0)'][1],
                        data_5['Log10 Luminosity (L0)'][1],
                        data_8['Log10 Luminosity (L0)'][1],
                        data_10['Log10 Luminosity (L0)'][1],
                        data_15['Log10 Luminosity (L0)'][1],
                        data_20['Log10 Luminosity (L0)'][1],
                        data_30['Log10 Luminosity (L0)'][1],
                        data_50['Log10 Luminosity (L0)'][1],
                        data_100['Log10 Luminosity (L0)'][1]])

temp_surface = np.array([data_0_1['Log10 Surface temperature (K)'][1],
                        data_0_5['Log10 Surface temperature (K)'][1],
                        data_1['Log10 Surface temperature (K)'][1],
                        data_2['Log10 Surface temperature (K)'][1],
                        data_3['Log10 Surface temperature (K)'][1],
                        data_5['Log10 Surface temperature (K)'][1],
                        data_8['Log10 Surface temperature (K)'][1],
                        data_10['Log10 Surface temperature (K)'][1],
                        data_15['Log10 Surface temperature (K)'][1],
                        data_20['Log10 Surface temperature (K)'][1],
                        data_30['Log10 Surface temperature (K)'][1],
                        data_50['Log10 Surface temperature (K)'][1],
                        data_100['Log10 Surface temperature (K)'][1]])

mass = np.array([data_0_1['Mass (M0)'][1],
                data_0_5['Mass (M0)'][1],
                data_1['Mass (M0)'][1],
                data_2['Mass (M0)'][1],
                data_3['Mass (M0)'][1],
                data_5['Mass (M0)'][1],
                data_8['Mass (M0)'][1],
                data_10['Mass (M0)'][1],
                data_15['Mass (M0)'][1],
                data_20['Mass (M0)'][1],
                data_30['Mass (M0)'][1],
                data_50['Mass (M0)'][1],
                data_100['Mass (M0)'][1]])

fig, ax = plt.subplots(2, 2, figsize=(14, 10))

ax[0][0].scatter(mass, temp_central, c='b')
ax[0][0].plot(mass, temp_central, c='b', alpha=0.4)
ax[0][0].grid();
ax[0][0].set_xlabel('Mass [$M_\odot$]')
ax[0][0].set_ylabel('Log$_{10}$ Central temperature [K]')
ax[0][0].set_title('Log$_{10}$ Central temperature for stars with different masses')

ax[0][1].scatter(mass, density_central, c='b')
ax[0][1].plot(mass, density_central, c='b', alpha=0.4)
ax[0][1].grid();
ax[0][1].set_xlabel('Mass [$M_\odot$]')
ax[0][1].set_ylabel('Log$_{10}$ Central density [kg m$^{-3}$]')
ax[0][1].set_title('Log$_{10}$ Central density for stars with different masses')

ax[1][0].scatter(mass, luminosity, c='b')
ax[1][0].plot(mass, luminosity, c='b', alpha=0.4)
ax[1][0].grid();
ax[1][0].set_xlabel('Mass [$M_\odot$]')
ax[1][0].set_ylabel('Log$_{10}$ Luminosity [$L_\odot$]')
ax[1][0].set_title('Log$_{10}$ Luminosity for stars with different masses')

ax[1][1].scatter(mass, temp_surface, c='b')
ax[1][1].plot(mass, temp_surface, c='b', alpha=0.4)
ax[1][1].grid();
ax[1][1].set_xlabel('Mass [$M_\odot$]')
ax[1][1].set_ylabel('Log$_{10}$ Surface temperature [K]')
ax[1][1].set_title('Log$_{10}$ Surface temperature for stars with different masses')

plt.tight_layout()

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 5))

ax.plot(data_0_1['Log10 Surface temperature (K)'], data_0_1['Log10 Luminosity (L0)'], c='#1f77b4', label='M=0.1 M$_\odot$')
ax.plot(data_0_5['Log10 Surface temperature (K)'], data_0_5['Log10 Luminosity (L0)'], c='#ff7f0e', label='M=0.5 M$_\odot$')
ax.plot(data_1['Log10 Surface temperature (K)'], data_1['Log10 Luminosity (L0)'], c='#2ca02c', label='M=M$_\odot$')
ax.plot(data_1_5['Log10 Surface temperature (K)'], data_1_5['Log10 Luminosity (L0)'], c='#9467bd', label='M=1.5 M$_\odot$')
#ax.plot(data_2['Log10 Surface temperature (K)'], data_2['Log10 Luminosity (L0)'], c=(1,0,1), label='M=2 M$_\odot$')
ax.plot(data_3['Log10 Surface temperature (K)'], data_3['Log10 Luminosity (L0)'], c='#bcbd22', label='M=3 M$_\odot$')
ax.plot(data_5['Log10 Surface temperature (K)'], data_5['Log10 Luminosity (L0)'], c='#8c564b', label='M=5 M$_\odot$')
#ax.plot(data_8['Log10 Surface temperature (K)'], data_8['Log10 Luminosity (L0)'], c=(1,0,0.25), label='M=8 M$_\odot$')
ax.plot(data_10['Log10 Surface temperature (K)'], data_10['Log10 Luminosity (L0)'], c='#d62728', label='M=10 M$_\odot$')
#ax.plot(data_15['Log10 Surface temperature (K)'], data_15['Log10 Luminosity (L0)'], c='b', label='M=15 M$_\odot$')
ax.plot(data_20['Log10 Surface temperature (K)'], data_20['Log10 Luminosity (L0)'], c='#e377c2', label='M=20 M$_\odot$')
#ax.plot(data_30['Log10 Surface temperature (K)'], data_30['Log10 Luminosity (L0)'], c='b', label='M=30 M$_\odot$')
#ax.plot(data_50['Log10 Surface temperature (K)'], data_50['Log10 Luminosity (L0)'], c='b', label='M=50 M$_\odot$')
ax.plot(data_100['Log10 Surface temperature (K)'], data_100['Log10 Luminosity (L0)'], c='#17becf', label='M=100 M$_\odot$')

#linestyle='--'



ax.grid();
plt.axis([4.95, 3.25, -5.2, 6.9])
ax.set_ylabel('Log$_{10}$ Luminosity [$L_\odot$]')
ax.set_xlabel('Log$_{10}$ Surface temperature [K]')
ax.set_title('Luminosity as a function of surface temperature for various stellar masses')

#plt.axis([max(data_0_1['Log10 Surface temperature (K)'])+0.02, min(data_0_1['Log10 Surface temperature (K)'])-0.02, 
          #min(data_0_1['Log10 Luminosity (L0)'])-0.2, max(data_0_1['Log10 Luminosity (L0)'])+0.2])
ax.legend()

# %%
met_0001 = pd.read_fwf('Stellar data/met0.0001.txt', names=col_names, index_col=0)
met_0003 = pd.read_fwf('Stellar data/met0.0003.txt', names=col_names, index_col=0)
met_001 = pd.read_fwf('Stellar data/met0.001.txt', names=col_names, index_col=0)
met_004 = pd.read_fwf('Stellar data/met0.004.txt', names=col_names, index_col=0)
met_01 = pd.read_fwf('Stellar data/met0.01.txt', names=col_names, index_col=0)
met_02 = pd.read_fwf('Stellar data/met0.02.txt', names=col_names, index_col=0)
met_03 = pd.read_fwf('Stellar data/met0.03.txt', names=col_names, index_col=0)

# %%
temp_central_met = np.array([met_0001['Log10 Central temperature (K)'][1],
                        met_0003['Log10 Central temperature (K)'][1],
                        met_001['Log10 Central temperature (K)'][1],
                        met_004['Log10 Central temperature (K)'][1],
                        met_01['Log10 Central temperature (K)'][1],
                        met_02['Log10 Central temperature (K)'][1],
                        met_03['Log10 Central temperature (K)'][1]])

dens_central_met = np.array([met_0001['Log10 Central density (kg m-3)'][1],
                        met_0003['Log10 Central density (kg m-3)'][1],
                        met_001['Log10 Central density (kg m-3)'][1],
                        met_004['Log10 Central density (kg m-3)'][1],
                        met_01['Log10 Central density (kg m-3)'][1],
                        met_02['Log10 Central density (kg m-3)'][1],
                        met_03['Log10 Central density (kg m-3)'][1]])

lumi_met = np.array([met_0001['Log10 Luminosity (L0)'][1],
                        met_0003['Log10 Luminosity (L0)'][1],
                        met_001['Log10 Luminosity (L0)'][1],
                        met_004['Log10 Luminosity (L0)'][1],
                        met_01['Log10 Luminosity (L0)'][1],
                        met_02['Log10 Luminosity (L0)'][1],
                        met_03['Log10 Luminosity (L0)'][1]])

temp_surface_met = np.array([met_0001['Log10 Surface temperature (K)'][1],
                        met_0003['Log10 Surface temperature (K)'][1],
                        met_001['Log10 Surface temperature (K)'][1],
                        met_004['Log10 Surface temperature (K)'][1],
                        met_01['Log10 Surface temperature (K)'][1],
                        met_02['Log10 Surface temperature (K)'][1],
                        met_03['Log10 Surface temperature (K)'][1]])

metallicity = np.array([0.0001, 0.0003, 0.001, 0.004, 0.01, 0.02, 0.03])

fig, ax = plt.subplots(2, 2, figsize=(14, 8))

ax[0][0].scatter(metallicity, temp_central_met, c='b')
ax[0][0].plot(metallicity, temp_central_met, c='b', alpha=0.4)
ax[0][0].grid();
ax[0][0].set_xlabel('Metallicity')
ax[0][0].set_ylabel('Log$_{10}$ Central temperature [K]')
ax[0][0].set_title('Log$_{10}$ Central temperature for stars with different metallicities')

ax[0][1].scatter(metallicity, dens_central_met, c='b')
ax[0][1].plot(metallicity, dens_central_met, c='b', alpha=0.4)
ax[0][1].grid();
ax[0][1].set_xlabel('Metallicity')
ax[0][1].set_ylabel('Log$_{10}$ Central denisty [kg m$^{-3}$]')
ax[0][1].set_title('Log$_{10}$ Central density for stars with different metallicities')

ax[1][0].scatter(metallicity, lumi_met, c='b')
ax[1][0].plot(metallicity, lumi_met, c='b', alpha=0.4)
ax[1][0].grid();
ax[1][0].set_xlabel('Metallicity')
ax[1][0].set_ylabel('Log$_{10}$ Luminosity [L$_\odot$]')
ax[1][0].set_title('Log$_{10}$ Luminosity for stars with different metallicities')

ax[1][1].scatter(metallicity, temp_surface_met, c='b')
ax[1][1].plot(metallicity, temp_surface_met, c='b', alpha=0.4)
ax[1][1].grid();
ax[1][1].set_xlabel('Metallicity')
ax[1][1].set_ylabel('Log$_{10}$ Surface temperature [K]')
ax[1][1].set_title('Log$_{10}$ Surface temperature for stars with different metallicities')

plt.tight_layout()

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 5))

ax.plot(met_0001['Log10 Surface temperature (K)'], met_0001['Log10 Luminosity (L0)'], c='#1f77b4', label='z=0.0001')
#ax.plot(met_0003['Log10 Surface temperature (K)'], met_0003['Log10 Luminosity (L0)'], c='#ff7f0e', label='z=0.0003')
ax.plot(met_001['Log10 Surface temperature (K)'], met_001['Log10 Luminosity (L0)'], c='#2ca02c', label='z=0.001')
#ax.plot(met_004['Log10 Surface temperature (K)'], met_004['Log10 Luminosity (L0)'], c='#9467bd', label='z=0.004')
ax.plot(met_01['Log10 Surface temperature (K)'], met_01['Log10 Luminosity (L0)'], c='#bcbd22', label='z=0.01')
#ax.plot(met_02['Log10 Surface temperature (K)'], met_02['Log10 Luminosity (L0)'], c='#8c564b', label='z=0.02')
ax.plot(met_03['Log10 Surface temperature (K)'], met_03['Log10 Luminosity (L0)'], c='#d62728', label='z=0.03')

#linestyle='--'


ax.grid();
plt.axis([4.07, 3.39, 0.5, 4.6])
ax.set_ylabel('Log$_{10}$ Luminosity [$L_\odot$]')
ax.set_xlabel('Log$_{10}$ Surface temperature [K]')
ax.set_title('Luminosity as a function of surface temperature for various stellar metallicities')

ax.legend()
